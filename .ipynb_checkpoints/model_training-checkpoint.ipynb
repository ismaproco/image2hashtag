# %%
import torch
from torch.utils import data
import random
import numpy as np
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision import  datasets, transforms, models
from torch.optim import lr_scheduler

# %%
device_to = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Create master dataset and split it into the train, test and valid
def build_dataloaders(batch_size):
    data_train = 'data/train'
    data_valid = 'data/valid'
    
    data_transforms = transforms.Compose([transforms.Resize(255),
                                          transforms.RandomRotation(20),
                                          transforms.RandomResizedCrop(224, scale=(0.7, 1.0), ratio=(0.90, 1.11)),
                                           transforms.RandomHorizontalFlip(),
                                          transforms.RandomVerticalFlip(),
                                           transforms.ToTensor(),
                                           transforms.Normalize([0.485, 0.456, 0.406],
                                                                [0.229, 0.224, 0.225])])

    validation_transforms = transforms.Compose([transforms.Resize(255),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                               [0.229, 0.224, 0.225])])

    # TODO: Load the datasets with ImageFolder
    train_data = datasets.ImageFolder(data_train, transform=data_transforms)
    test_data = datasets.ImageFolder(data_valid, transform=validation_transforms)
    
#     n = len(master_dataset)  # how many total elements you have
#     n_test = int( n * .1 )  # number of test/val elements (.1 == 10%)
#     n_train = n - 2 * n_test
#     idx = list(range(n))  # indices to all elements
#     train_idx = idx[:n_train]
#     val_idx = idx[n_train:(n_train + n_test)]
#     test_idx = idx[(n_train + n_test):]

#     train_data = data.Subset(master_dataset, train_idx)
#     valid_data = data.Subset(master_dataset, val_idx)
#     test_data = data.Subset(master_dataset, test_idx)
    
    train = torch.utils.data.DataLoader(train_data, batch_size, shuffle=True)
    test = torch.utils.data.DataLoader(test_data, batch_size)
    class_names = train_data.classes
    return train, test, class_names

# %%
global_batch_size = 50
train_loader, test_loader, class_names = build_dataloaders(global_batch_size)
print(class_names)
# Out:
# ['autumn', 'beach', 'christmas', 'easter', 'fashion', 'friends', 'happy', 'landscape', 'love', 'mountains', 'nature', 'snow', 'summer', 'sunset']

# %%
# IEJG - I will test the dataloaders before starting the training.
### Define a function to view the images
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

def test_image_loaders():
    images, label = next(iter(train_loader))
    imshow(images[0,:])
    imshow(images[1,:])
    imshow(images[2,:])
    
    images, label = next(iter(test_loader))
    imshow(images[0,:])
    imshow(images[1,:])
    imshow(images[2,:])
    
test_image_loaders()

# %%
def load_base_model(device, classes):
    model = models.resnet50(pretrained=True)
    # Use GPU if it's available
    

    ## Freeze parameters so we don't backprop through them
    for param in model.parameters():
        param.requires_grad = False
    
    for param in model.layer3.parameters():
        param.requires_grad = False
        
    for param in model.layer4.parameters():
        param.requires_grad = False

    from collections import OrderedDict
    fc = nn.Sequential(OrderedDict([
                              ('fc1', nn.Linear(2048, 1024)),
                              ('relu', nn.ReLU()),
                              ('fc2', nn.Linear(1024, len(classes))),
                              ('output', nn.LogSoftmax(dim=1))
                              ]))

    model.fc = fc
    model.to(device)
    return model

# %%
len(train_loader)
# Out:
# 24

# %%
def train(inputs, labels, device, model, optimizer, criterion, running_loss):
    model.train()
    inputs, labels = inputs.to(device), labels.to(device)
    optimizer.zero_grad()
    logps = model.forward(inputs)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    return running_loss

# %%
def validate(loader, device, model, criterion):
    model.eval()
    test_loss = 0.0
    accuracy = 0.0
    valid_loss = 0.0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            logps = model.forward(inputs)
            batch_loss = criterion(logps, labels)
            test_loss += batch_loss.item()
            # Calculate accuracy
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            valid_loss += batch_loss.item()*inputs.size(0)

    valid_loss = valid_loss/len(loader.dataset)
    return test_loss, accuracy, valid_loss

# %%
def accuracy_calc(loader, model,epochs, epoch, running_loss, test_loss, accuracy, valid_loss, valid_loss_min, max_accu):
    steps = len(loader)
    print(f"Epoch {epoch+1}/{epochs}.. "
          f"Step: {steps}.. "
          f"Train loss: {running_loss/steps:.3f}.. "
          f"Test loss: {test_loss/len(loader):.3f}.. "
          f"Test accuracy: {accuracy/len(loader):.3f}.. "
          f"Valid Loss: {valid_loss:.3f}")

    #saving max accuracy
    calc_accu = accuracy/len(loader)
    print(f'lets see {calc_accu} / {max_accu}')
    if max_accu < calc_accu:
        print(f"++++++ Accuracy increase {max_accu:.3f} to {calc_accu}   ===== Saving model =====")
        torch.save(model.state_dict(), 'model_resnet_maxaccu_152_p99.pt')
        max_accu = calc_accu

    # saving max valid_loss
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_resnet152_p99.pt')
        valid_loss_min = valid_loss
    return valid_loss_min, max_accu

# %%
def trainer_loop(train_loader, test_loader, model, epochs, lr, device, max_accu = 0.0):
    optimizer = optim.Adam([
                        {'params': model.layer3.parameters()},
                        {'params': model.layer4.parameters()},
                       {'params': model.fc.parameters()}], lr)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min')
    criterion = nn.NLLLoss()
    print_every = 5
    valid_loss_min = np.Inf # set initial "min" to infinity
    
    for epoch in range(epochs):
        steps = 0
        running_loss = 0
        for inputs, labels in train_loader:
            steps += 1
            running_loss = train(inputs, labels, device, model, optimizer, criterion, running_loss)
            print(f"Epoch {epoch+1}/{epochs}.. "
              f"Step: {steps}/{len(train_loader)}.. "
              f"Train loss: {running_loss/steps:.3f}.. ")
        test_loss, accuracy, valid_loss = validate(test_loader, device, model, criterion)
        valid_loss_min, max_accu = accuracy_calc(test_loader, model, epochs, epoch, running_loss, test_loss, accuracy, valid_loss, valid_loss_min, max_accu)
        print(test_loss, accuracy, valid_loss, max_accu)
        scheduler.step(valid_loss)
    return model

# %%
#final_model = trainer_loop(train_loader, test_loader,load_base_model(device_to, class_names),epochs=15,lr =0.0001,device=device_to )
final_model = trainer_loop(train_loader, test_loader,final_model,epochs=30,lr =0.00001,device=device_to, max_accu = 0.84 )
# Out:
# Epoch 1/30.. Step: 1/24.. Train loss: 0.473..
# Epoch 1/30.. Step: 2/24.. Train loss: 0.424..
# Epoch 1/30.. Step: 3/24.. Train loss: 0.480..
# Epoch 1/30.. Step: 4/24.. Train loss: 0.497..
# Epoch 1/30.. Step: 5/24.. Train loss: 0.511..
# Epoch 1/30.. Step: 6/24.. Train loss: 0.513..
# Epoch 1/30.. Step: 7/24.. Train loss: 0.512..
# Epoch 1/30.. Step: 8/24.. Train loss: 0.503..
# Epoch 1/30.. Step: 9/24.. Train loss: 0.499..
# Epoch 1/30.. Step: 10/24.. Train loss: 0.497..
# Epoch 1/30.. Step: 11/24.. Train loss: 0.496..
# Epoch 1/30.. Step: 12/24.. Train loss: 0.484..
# Epoch 1/30.. Step: 13/24.. Train loss: 0.473..
# Epoch 1/30.. Step: 14/24.. Train loss: 0.472..
# Epoch 1/30.. Step: 15/24.. Train loss: 0.473..
# Epoch 1/30.. Step: 16/24.. Train loss: 0.474..
# Epoch 1/30.. Step: 17/24.. Train loss: 0.475..
# Epoch 1/30.. Step: 18/24.. Train loss: 0.482..
# Epoch 1/30.. Step: 19/24.. Train loss: 0.481..
# Epoch 1/30.. Step: 20/24.. Train loss: 0.496..
# Epoch 1/30.. Step: 21/24.. Train loss: 0.502..
# Epoch 1/30.. Step: 22/24.. Train loss: 0.498..
# Epoch 1/30.. Step: 23/24.. Train loss: 0.496..
# Epoch 1/30.. Step: 24/24.. Train loss: 0.492..
# Epoch 1/30.. Step: 3.. Train loss: 3.933.. Test loss: 0.378.. Test accuracy: 0.857.. Valid Loss: 0.347
# lets see 0.8574999968210856 / 0.84
# ++++++ Accuracy increase 0.840 to 0.8574999968210856   ===== Saving model =====
# Validation loss decreased (inf --> 0.347404).  Saving model ...
# 1.13328355550766 2.572499990463257 0.3474043782415061 0.8574999968210856
# Epoch 2/30.. Step: 1/24.. Train loss: 0.411..
# Epoch 2/30.. Step: 2/24.. Train loss: 0.490..
# Epoch 2/30.. Step: 3/24.. Train loss: 0.412..
# Epoch 2/30.. Step: 4/24.. Train loss: 0.423..
# Epoch 2/30.. Step: 5/24.. Train loss: 0.442..
# Epoch 2/30.. Step: 6/24.. Train loss: 0.448..
# Epoch 2/30.. Step: 7/24.. Train loss: 0.439..
# Epoch 2/30.. Step: 8/24.. Train loss: 0.435..
# Epoch 2/30.. Step: 9/24.. Train loss: 0.438..
# Epoch 2/30.. Step: 10/24.. Train loss: 0.441..
# Epoch 2/30.. Step: 11/24.. Train loss: 0.436..
# Epoch 2/30.. Step: 12/24.. Train loss: 0.443..
# Epoch 2/30.. Step: 13/24.. Train loss: 0.448..
# Epoch 2/30.. Step: 14/24.. Train loss: 0.449..
# Epoch 2/30.. Step: 15/24.. Train loss: 0.455..
# Epoch 2/30.. Step: 16/24.. Train loss: 0.456..
# Epoch 2/30.. Step: 17/24.. Train loss: 0.459..
# Epoch 2/30.. Step: 18/24.. Train loss: 0.456..
# Epoch 2/30.. Step: 19/24.. Train loss: 0.460..
# Epoch 2/30.. Step: 20/24.. Train loss: 0.465..
# Epoch 2/30.. Step: 21/24.. Train loss: 0.461..
# Epoch 2/30.. Step: 22/24.. Train loss: 0.454..
# Epoch 2/30.. Step: 23/24.. Train loss: 0.453..
# Epoch 2/30.. Step: 24/24.. Train loss: 0.455..
# Epoch 2/30.. Step: 3.. Train loss: 3.641.. Test loss: 0.414.. Test accuracy: 0.788.. Valid Loss: 0.364
# lets see 0.7883333166440328 / 0.8574999968210856
# 1.2408118098974228 2.3649999499320984 0.363995101688237 0.8574999968210856
# Epoch 3/30.. Step: 1/24.. Train loss: 0.440..
# Epoch 3/30.. Step: 2/24.. Train loss: 0.510..
# Epoch 3/30.. Step: 3/24.. Train loss: 0.513..
# Epoch 3/30.. Step: 4/24.. Train loss: 0.545..
# Epoch 3/30.. Step: 5/24.. Train loss: 0.562..
# Epoch 3/30.. Step: 6/24.. Train loss: 0.549..
# Epoch 3/30.. Step: 7/24.. Train loss: 0.588..
# Epoch 3/30.. Step: 8/24.. Train loss: 0.564..
# Epoch 3/30.. Step: 9/24.. Train loss: 0.561..
# Epoch 3/30.. Step: 10/24.. Train loss: 0.554..
# Epoch 3/30.. Step: 11/24.. Train loss: 0.536..
# Epoch 3/30.. Step: 12/24.. Train loss: 0.544..
# Epoch 3/30.. Step: 13/24.. Train loss: 0.543..
# Epoch 3/30.. Step: 14/24.. Train loss: 0.537..
# Epoch 3/30.. Step: 15/24.. Train loss: 0.531..
# Epoch 3/30.. Step: 16/24.. Train loss: 0.522..
# Epoch 3/30.. Step: 17/24.. Train loss: 0.521..
# Epoch 3/30.. Step: 18/24.. Train loss: 0.518..
# Epoch 3/30.. Step: 19/24.. Train loss: 0.507..
# Epoch 3/30.. Step: 20/24.. Train loss: 0.503..
# Epoch 3/30.. Step: 21/24.. Train loss: 0.500..
# Epoch 3/30.. Step: 22/24.. Train loss: 0.495..
# Epoch 3/30.. Step: 23/24.. Train loss: 0.497..
# Epoch 3/30.. Step: 24/24.. Train loss: 0.487..
# Epoch 3/30.. Step: 3.. Train loss: 3.898.. Test loss: 0.415.. Test accuracy: 0.816.. Valid Loss: 0.367
# lets see 0.815833330154419 / 0.8574999968210856
# 1.2437446266412735 2.447499990463257 0.3667491337862508 0.8574999968210856
# Epoch 4/30.. Step: 1/24.. Train loss: 0.353..
# Epoch 4/30.. Step: 2/24.. Train loss: 0.318..
# Epoch 4/30.. Step: 3/24.. Train loss: 0.473..
# Epoch 4/30.. Step: 4/24.. Train loss: 0.434..
# Epoch 4/30.. Step: 5/24.. Train loss: 0.449..
# Epoch 4/30.. Step: 6/24.. Train loss: 0.442..
# Epoch 4/30.. Step: 7/24.. Train loss: 0.475..
# Epoch 4/30.. Step: 8/24.. Train loss: 0.492..
# Epoch 4/30.. Step: 9/24.. Train loss: 0.500..
# Epoch 4/30.. Step: 10/24.. Train loss: 0.500..
# Epoch 4/30.. Step: 11/24.. Train loss: 0.493..
# Epoch 4/30.. Step: 12/24.. Train loss: 0.498..
# Epoch 4/30.. Step: 13/24.. Train loss: 0.515..
# Epoch 4/30.. Step: 14/24.. Train loss: 0.512..
# Epoch 4/30.. Step: 15/24.. Train loss: 0.509..
# Epoch 4/30.. Step: 16/24.. Train loss: 0.511..
# Epoch 4/30.. Step: 17/24.. Train loss: 0.521..
# Epoch 4/30.. Step: 18/24.. Train loss: 0.509..
# Epoch 4/30.. Step: 19/24.. Train loss: 0.498..
# Epoch 4/30.. Step: 20/24.. Train loss: 0.488..
# Epoch 4/30.. Step: 21/24.. Train loss: 0.485..
# Epoch 4/30.. Step: 22/24.. Train loss: 0.481..
# Epoch 4/30.. Step: 23/24.. Train loss: 0.476..
# Epoch 4/30.. Step: 24/24.. Train loss: 0.493..
# Epoch 4/30.. Step: 3.. Train loss: 3.940.. Test loss: 0.423.. Test accuracy: 0.795.. Valid Loss: 0.367
# lets see 0.7949999968210856 / 0.8574999968210856
# 1.2682270854711533 2.384999990463257 0.3673343450344842 0.8574999968210856
# Epoch 5/30.. Step: 1/24.. Train loss: 0.355..
# Epoch 5/30.. Step: 2/24.. Train loss: 0.379..
# Epoch 5/30.. Step: 3/24.. Train loss: 0.421..
# Epoch 5/30.. Step: 4/24.. Train loss: 0.445..
# Epoch 5/30.. Step: 5/24.. Train loss: 0.435..
# Epoch 5/30.. Step: 6/24.. Train loss: 0.462..
# Epoch 5/30.. Step: 7/24.. Train loss: 0.438..
# Epoch 5/30.. Step: 8/24.. Train loss: 0.473..
# Epoch 5/30.. Step: 9/24.. Train loss: 0.484..
# Epoch 5/30.. Step: 10/24.. Train loss: 0.492..
# Epoch 5/30.. Step: 11/24.. Train loss: 0.488..
# Epoch 5/30.. Step: 12/24.. Train loss: 0.483..
# Epoch 5/30.. Step: 13/24.. Train loss: 0.474..
# Epoch 5/30.. Step: 14/24.. Train loss: 0.478..
# Epoch 5/30.. Step: 15/24.. Train loss: 0.478..
# Epoch 5/30.. Step: 16/24.. Train loss: 0.468..
# Epoch 5/30.. Step: 17/24.. Train loss: 0.470..
# Epoch 5/30.. Step: 18/24.. Train loss: 0.471..
# Epoch 5/30.. Step: 19/24.. Train loss: 0.483..
# Epoch 5/30.. Step: 20/24.. Train loss: 0.483..
# Epoch 5/30.. Step: 21/24.. Train loss: 0.477..
# Epoch 5/30.. Step: 22/24.. Train loss: 0.485..
# Epoch 5/30.. Step: 23/24.. Train loss: 0.488..
# Epoch 5/30.. Step: 24/24.. Train loss: 0.486..
# Epoch 5/30.. Step: 3.. Train loss: 3.890.. Test loss: 0.406.. Test accuracy: 0.822.. Valid Loss: 0.357
# lets see 0.8224999904632568 / 0.8574999968210856
# 1.2172096818685532 2.4674999713897705 0.357172090174823 0.8574999968210856
# Epoch 6/30.. Step: 1/24.. Train loss: 0.430..
# Epoch 6/30.. Step: 2/24.. Train loss: 0.474..
# Epoch 6/30.. Step: 3/24.. Train loss: 0.445..
# Epoch 6/30.. Step: 4/24.. Train loss: 0.442..
# Epoch 6/30.. Step: 5/24.. Train loss: 0.462..
# Epoch 6/30.. Step: 6/24.. Train loss: 0.444..
# Epoch 6/30.. Step: 7/24.. Train loss: 0.436..
# Epoch 6/30.. Step: 8/24.. Train loss: 0.452..
# Epoch 6/30.. Step: 9/24.. Train loss: 0.449..
# Epoch 6/30.. Step: 10/24.. Train loss: 0.456..
# Epoch 6/30.. Step: 11/24.. Train loss: 0.466..
# Epoch 6/30.. Step: 12/24.. Train loss: 0.457..
# Epoch 6/30.. Step: 13/24.. Train loss: 0.466..
# Epoch 6/30.. Step: 14/24.. Train loss: 0.477..
# Epoch 6/30.. Step: 15/24.. Train loss: 0.475..
# Epoch 6/30.. Step: 16/24.. Train loss: 0.468..
# Epoch 6/30.. Step: 17/24.. Train loss: 0.457..
# Epoch 6/30.. Step: 18/24.. Train loss: 0.449..
# Epoch 6/30.. Step: 19/24.. Train loss: 0.449..
# Epoch 6/30.. Step: 20/24.. Train loss: 0.444..
# Epoch 6/30.. Step: 21/24.. Train loss: 0.450..
# Epoch 6/30.. Step: 22/24.. Train loss: 0.462..
# Epoch 6/30.. Step: 23/24.. Train loss: 0.477..
# Epoch 6/30.. Step: 24/24.. Train loss: 0.490..
# Epoch 6/30.. Step: 3.. Train loss: 3.916.. Test loss: 0.401.. Test accuracy: 0.822.. Valid Loss: 0.350
# lets see 0.8224999904632568 / 0.8574999968210856
# 1.2036733776330948 2.4674999713897705 0.34970242838407384 0.8574999968210856
# Epoch 7/30.. Step: 1/24.. Train loss: 0.336..
# Epoch 7/30.. Step: 2/24.. Train loss: 0.483..
# Epoch 7/30.. Step: 3/24.. Train loss: 0.463..
# Epoch 7/30.. Step: 4/24.. Train loss: 0.441..
# Epoch 7/30.. Step: 5/24.. Train loss: 0.426..
# Epoch 7/30.. Step: 6/24.. Train loss: 0.431..
# Epoch 7/30.. Step: 7/24.. Train loss: 0.433..
# Epoch 7/30.. Step: 8/24.. Train loss: 0.433..
# Epoch 7/30.. Step: 9/24.. Train loss: 0.426..
# Epoch 7/30.. Step: 10/24.. Train loss: 0.453..
# Epoch 7/30.. Step: 11/24.. Train loss: 0.448..
# Epoch 7/30.. Step: 12/24.. Train loss: 0.439..
# Epoch 7/30.. Step: 13/24.. Train loss: 0.431..
# Epoch 7/30.. Step: 14/24.. Train loss: 0.430..
# Epoch 7/30.. Step: 15/24.. Train loss: 0.435..
# Epoch 7/30.. Step: 16/24.. Train loss: 0.445..
# Epoch 7/30.. Step: 17/24.. Train loss: 0.445..
# Epoch 7/30.. Step: 18/24.. Train loss: 0.441..
# Epoch 7/30.. Step: 19/24.. Train loss: 0.450..
# Epoch 7/30.. Step: 20/24.. Train loss: 0.440..
# Epoch 7/30.. Step: 21/24.. Train loss: 0.444..
# Epoch 7/30.. Step: 22/24.. Train loss: 0.444..
# Epoch 7/30.. Step: 23/24.. Train loss: 0.442..
# Epoch 7/30.. Step: 24/24.. Train loss: 0.449..
# Epoch 7/30.. Step: 3.. Train loss: 3.588.. Test loss: 0.449.. Test accuracy: 0.788.. Valid Loss: 0.377
# lets see 0.7883333166440328 / 0.8574999968210856
# 1.346939742565155 2.3649999499320984 0.37711972512047864 0.8574999968210856
# Epoch 8/30.. Step: 1/24.. Train loss: 0.505..
# Epoch 8/30.. Step: 2/24.. Train loss: 0.432..
# Epoch 8/30.. Step: 3/24.. Train loss: 0.433..
# Epoch 8/30.. Step: 4/24.. Train loss: 0.417..
# Epoch 8/30.. Step: 5/24.. Train loss: 0.444..
# Epoch 8/30.. Step: 6/24.. Train loss: 0.505..
# Epoch 8/30.. Step: 7/24.. Train loss: 0.495..
# Epoch 8/30.. Step: 8/24.. Train loss: 0.504..
# Epoch 8/30.. Step: 9/24.. Train loss: 0.509..
# Epoch 8/30.. Step: 10/24.. Train loss: 0.493..
# Epoch 8/30.. Step: 11/24.. Train loss: 0.483..
# Epoch 8/30.. Step: 12/24.. Train loss: 0.475..
# Epoch 8/30.. Step: 13/24.. Train loss: 0.477..
# Epoch 8/30.. Step: 14/24.. Train loss: 0.484..
# Epoch 8/30.. Step: 15/24.. Train loss: 0.484..
# Epoch 8/30.. Step: 16/24.. Train loss: 0.473..
# Epoch 8/30.. Step: 17/24.. Train loss: 0.470..
# Epoch 8/30.. Step: 18/24.. Train loss: 0.486..
# Epoch 8/30.. Step: 19/24.. Train loss: 0.500..
# Epoch 8/30.. Step: 20/24.. Train loss: 0.501..
# Epoch 8/30.. Step: 21/24.. Train loss: 0.497..
# Epoch 8/30.. Step: 22/24.. Train loss: 0.499..
# Epoch 8/30.. Step: 23/24.. Train loss: 0.497..
# Epoch 8/30.. Step: 24/24.. Train loss: 0.509..
# Epoch 8/30.. Step: 3.. Train loss: 4.076.. Test loss: 0.396.. Test accuracy: 0.843.. Valid Loss: 0.355
# lets see 0.8433333237965902 / 0.8574999968210856
# 1.1872699409723282 2.5299999713897705 0.35526685391006796 0.8574999968210856
# Epoch 9/30.. Step: 1/24.. Train loss: 0.567..
# Epoch 9/30.. Step: 2/24.. Train loss: 0.570..
# Epoch 9/30.. Step: 3/24.. Train loss: 0.492..
# Epoch 9/30.. Step: 4/24.. Train loss: 0.459..
# Epoch 9/30.. Step: 5/24.. Train loss: 0.463..
# Epoch 9/30.. Step: 6/24.. Train loss: 0.471..
# Epoch 9/30.. Step: 7/24.. Train loss: 0.489..
# Epoch 9/30.. Step: 8/24.. Train loss: 0.484..
# Epoch 9/30.. Step: 9/24.. Train loss: 0.474..
# Epoch 9/30.. Step: 10/24.. Train loss: 0.486..
# Epoch 9/30.. Step: 11/24.. Train loss: 0.494..
# Epoch 9/30.. Step: 12/24.. Train loss: 0.499..
# Epoch 9/30.. Step: 13/24.. Train loss: 0.505..
# Epoch 9/30.. Step: 14/24.. Train loss: 0.512..
# Epoch 9/30.. Step: 15/24.. Train loss: 0.511..
# Epoch 9/30.. Step: 16/24.. Train loss: 0.511..
# Epoch 9/30.. Step: 17/24.. Train loss: 0.514..
# Epoch 9/30.. Step: 18/24.. Train loss: 0.518..
# Epoch 9/30.. Step: 19/24.. Train loss: 0.525..
# Epoch 9/30.. Step: 20/24.. Train loss: 0.515..
# Epoch 9/30.. Step: 21/24.. Train loss: 0.515..
# Epoch 9/30.. Step: 22/24.. Train loss: 0.513..
# Epoch 9/30.. Step: 23/24.. Train loss: 0.504..
# Epoch 9/30.. Step: 24/24.. Train loss: 0.522..
# Epoch 9/30.. Step: 3.. Train loss: 4.177.. Test loss: 0.432.. Test accuracy: 0.788.. Valid Loss: 0.370
# lets see 0.7883333166440328 / 0.8574999968210856
# 1.29552561044693 2.3649999499320984 0.3696784695674633 0.8574999968210856
# Epoch 10/30.. Step: 1/24.. Train loss: 0.401..
# Epoch 10/30.. Step: 2/24.. Train loss: 0.432..
# Epoch 10/30.. Step: 3/24.. Train loss: 0.410..
# Epoch 10/30.. Step: 4/24.. Train loss: 0.449..
# Epoch 10/30.. Step: 5/24.. Train loss: 0.456..
# Epoch 10/30.. Step: 6/24.. Train loss: 0.457..
# Epoch 10/30.. Step: 7/24.. Train loss: 0.445..
# Epoch 10/30.. Step: 8/24.. Train loss: 0.446..
# Epoch 10/30.. Step: 9/24.. Train loss: 0.445..
# Epoch 10/30.. Step: 10/24.. Train loss: 0.438..
# Epoch 10/30.. Step: 11/24.. Train loss: 0.434..
# Epoch 10/30.. Step: 12/24.. Train loss: 0.438..
# Epoch 10/30.. Step: 13/24.. Train loss: 0.431..
# Epoch 10/30.. Step: 14/24.. Train loss: 0.442..
# Epoch 10/30.. Step: 15/24.. Train loss: 0.460..
# Epoch 10/30.. Step: 16/24.. Train loss: 0.461..
# Epoch 10/30.. Step: 17/24.. Train loss: 0.458..
# Epoch 10/30.. Step: 18/24.. Train loss: 0.462..
# Epoch 10/30.. Step: 19/24.. Train loss: 0.464..
# Epoch 10/30.. Step: 20/24.. Train loss: 0.457..
# Epoch 10/30.. Step: 21/24.. Train loss: 0.461..
# Epoch 10/30.. Step: 22/24.. Train loss: 0.468..
# Epoch 10/30.. Step: 23/24.. Train loss: 0.463..
# Epoch 10/30.. Step: 24/24.. Train loss: 0.475..
# Epoch 10/30.. Step: 3.. Train loss: 3.803.. Test loss: 0.408.. Test accuracy: 0.837.. Valid Loss: 0.364
# lets see 0.8366666634877523 / 0.8574999968210856
# 1.2237194329500198 2.509999990463257 0.36419262891185694 0.8574999968210856
# Epoch 11/30.. Step: 1/24.. Train loss: 0.443..
# Epoch 11/30.. Step: 2/24.. Train loss: 0.461..
# Epoch 11/30.. Step: 3/24.. Train loss: 0.434..
# Epoch 11/30.. Step: 4/24.. Train loss: 0.398..
# Epoch 11/30.. Step: 5/24.. Train loss: 0.424..
# Epoch 11/30.. Step: 6/24.. Train loss: 0.513..
# Epoch 11/30.. Step: 7/24.. Train loss: 0.519..
# Epoch 11/30.. Step: 8/24.. Train loss: 0.515..
# Epoch 11/30.. Step: 9/24.. Train loss: 0.518..
# Epoch 11/30.. Step: 10/24.. Train loss: 0.518..
# Epoch 11/30.. Step: 11/24.. Train loss: 0.498..
# Epoch 11/30.. Step: 12/24.. Train loss: 0.491..
# Epoch 11/30.. Step: 13/24.. Train loss: 0.476..
# Epoch 11/30.. Step: 14/24.. Train loss: 0.472..
# Epoch 11/30.. Step: 15/24.. Train loss: 0.474..
# Epoch 11/30.. Step: 16/24.. Train loss: 0.464..
# Epoch 11/30.. Step: 17/24.. Train loss: 0.485..
# Epoch 11/30.. Step: 18/24.. Train loss: 0.483..
# Epoch 11/30.. Step: 19/24.. Train loss: 0.491..
# Epoch 11/30.. Step: 20/24.. Train loss: 0.490..
# Epoch 11/30.. Step: 21/24.. Train loss: 0.493..
# Epoch 11/30.. Step: 22/24.. Train loss: 0.502..
# Epoch 11/30.. Step: 23/24.. Train loss: 0.510..
# Epoch 11/30.. Step: 24/24.. Train loss: 0.505..
# Epoch 11/30.. Step: 3.. Train loss: 4.044.. Test loss: 0.418.. Test accuracy: 0.809.. Valid Loss: 0.365
# lets see 0.8091666499773661 / 0.8574999968210856
# 1.2528831213712692 2.4274999499320984 0.36543912800221606 0.8574999968210856
# Epoch 12/30.. Step: 1/24.. Train loss: 0.393..
# Epoch 12/30.. Step: 2/24.. Train loss: 0.505..
# Epoch 12/30.. Step: 3/24.. Train loss: 0.527..
# Epoch 12/30.. Step: 4/24.. Train loss: 0.564..
# Epoch 12/30.. Step: 5/24.. Train loss: 0.549..
# Epoch 12/30.. Step: 6/24.. Train loss: 0.508..
# Epoch 12/30.. Step: 7/24.. Train loss: 0.498..
# Epoch 12/30.. Step: 8/24.. Train loss: 0.504..
# Epoch 12/30.. Step: 9/24.. Train loss: 0.489..
# Epoch 12/30.. Step: 10/24.. Train loss: 0.473..
# Epoch 12/30.. Step: 11/24.. Train loss: 0.463..
# Epoch 12/30.. Step: 12/24.. Train loss: 0.455..
# Epoch 12/30.. Step: 13/24.. Train loss: 0.459..
# Epoch 12/30.. Step: 14/24.. Train loss: 0.459..
# Epoch 12/30.. Step: 15/24.. Train loss: 0.460..
# Epoch 12/30.. Step: 16/24.. Train loss: 0.467..
# Epoch 12/30.. Step: 17/24.. Train loss: 0.463..
# Epoch 12/30.. Step: 18/24.. Train loss: 0.468..
# Epoch 12/30.. Step: 19/24.. Train loss: 0.466..
# Epoch 12/30.. Step: 20/24.. Train loss: 0.465..
# Epoch 12/30.. Step: 21/24.. Train loss: 0.471..
# Epoch 12/30.. Step: 22/24.. Train loss: 0.477..
# Epoch 12/30.. Step: 23/24.. Train loss: 0.472..
# Epoch 12/30.. Step: 24/24.. Train loss: 0.481..
# Epoch 12/30.. Step: 3.. Train loss: 3.847.. Test loss: 0.427.. Test accuracy: 0.816.. Valid Loss: 0.370
# lets see 0.815833330154419 / 0.8574999968210856
# 1.2803027033805847 2.447499990463257 0.36993641380606024 0.8574999968210856
# Epoch 13/30.. Step: 1/24.. Train loss: 0.334..
# Epoch 13/30.. Step: 2/24.. Train loss: 0.308..
# Epoch 13/30.. Step: 3/24.. Train loss: 0.419..
# Epoch 13/30.. Step: 4/24.. Train loss: 0.433..
# Epoch 13/30.. Step: 5/24.. Train loss: 0.457..
# Epoch 13/30.. Step: 6/24.. Train loss: 0.460..
# Epoch 13/30.. Step: 7/24.. Train loss: 0.426..
# Epoch 13/30.. Step: 8/24.. Train loss: 0.457..
# Epoch 13/30.. Step: 9/24.. Train loss: 0.452..
# Epoch 13/30.. Step: 10/24.. Train loss: 0.450..
# Epoch 13/30.. Step: 11/24.. Train loss: 0.441..
# Epoch 13/30.. Step: 12/24.. Train loss: 0.446..
# Epoch 13/30.. Step: 13/24.. Train loss: 0.442..
# Epoch 13/30.. Step: 14/24.. Train loss: 0.455..
# Epoch 13/30.. Step: 15/24.. Train loss: 0.459..
# Epoch 13/30.. Step: 16/24.. Train loss: 0.453..
# Epoch 13/30.. Step: 17/24.. Train loss: 0.450..
# Epoch 13/30.. Step: 18/24.. Train loss: 0.458..
# Epoch 13/30.. Step: 19/24.. Train loss: 0.462..
# Epoch 13/30.. Step: 20/24.. Train loss: 0.455..
# Epoch 13/30.. Step: 21/24.. Train loss: 0.455..
# Epoch 13/30.. Step: 22/24.. Train loss: 0.453..
# Epoch 13/30.. Step: 23/24.. Train loss: 0.457..
# Epoch 13/30.. Step: 24/24.. Train loss: 0.463..
# Epoch 13/30.. Step: 3.. Train loss: 3.702.. Test loss: 0.444.. Test accuracy: 0.775.. Valid Loss: 0.381
# lets see 0.774999996026357 / 0.8574999968210856
# 1.332106813788414 2.324999988079071 0.38056016353697614 0.8574999968210856
# Epoch 14/30.. Step: 1/24.. Train loss: 0.469..
# Epoch 14/30.. Step: 2/24.. Train loss: 0.476..
# Epoch 14/30.. Step: 3/24.. Train loss: 0.471..
# Epoch 14/30.. Step: 4/24.. Train loss: 0.524..
# Epoch 14/30.. Step: 5/24.. Train loss: 0.517..
# Epoch 14/30.. Step: 6/24.. Train loss: 0.503..
# Epoch 14/30.. Step: 7/24.. Train loss: 0.476..
# Epoch 14/30.. Step: 8/24.. Train loss: 0.465..
# Epoch 14/30.. Step: 9/24.. Train loss: 0.465..
# Epoch 14/30.. Step: 10/24.. Train loss: 0.460..
# Epoch 14/30.. Step: 11/24.. Train loss: 0.461..
# Epoch 14/30.. Step: 12/24.. Train loss: 0.459..
# Epoch 14/30.. Step: 13/24.. Train loss: 0.453..
# Epoch 14/30.. Step: 14/24.. Train loss: 0.449..
# Epoch 14/30.. Step: 15/24.. Train loss: 0.462..
# Epoch 14/30.. Step: 16/24.. Train loss: 0.468..
# Epoch 14/30.. Step: 17/24.. Train loss: 0.470..
# Epoch 14/30.. Step: 18/24.. Train loss: 0.473..
# Epoch 14/30.. Step: 19/24.. Train loss: 0.475..
# Epoch 14/30.. Step: 20/24.. Train loss: 0.474..
# Epoch 14/30.. Step: 21/24.. Train loss: 0.473..
# Epoch 14/30.. Step: 22/24.. Train loss: 0.482..
# Epoch 14/30.. Step: 23/24.. Train loss: 0.480..
# Epoch 14/30.. Step: 24/24.. Train loss: 0.486..
# Epoch 14/30.. Step: 3.. Train loss: 3.886.. Test loss: 0.441.. Test accuracy: 0.782.. Valid Loss: 0.380
# lets see 0.7816666563351949 / 0.8574999968210856
# 1.3240548372268677 2.3449999690055847 0.37976808691846914 0.8574999968210856
# Epoch 15/30.. Step: 1/24.. Train loss: 0.548..
# Epoch 15/30.. Step: 2/24.. Train loss: 0.474..
# Epoch 15/30.. Step: 3/24.. Train loss: 0.529..
# Epoch 15/30.. Step: 4/24.. Train loss: 0.529..
# Epoch 15/30.. Step: 5/24.. Train loss: 0.557..
# Epoch 15/30.. Step: 6/24.. Train loss: 0.544..
# Epoch 15/30.. Step: 7/24.. Train loss: 0.527..
# Epoch 15/30.. Step: 8/24.. Train loss: 0.527..
# Epoch 15/30.. Step: 9/24.. Train loss: 0.512..
# Epoch 15/30.. Step: 10/24.. Train loss: 0.502..
# Epoch 15/30.. Step: 11/24.. Train loss: 0.494..

# %%
# Out:
# 1020
# '_DataLoader__initialized, __class__, __delattr__, __dict__, __dir__, __doc__, __eq__, __format__, __ge__, __getattribute__, __gt__, __hash__, __init__, __init_subclass__, __iter__, __le__, __len__, __lt__, __module__, __ne__, __new__, __reduce__, __reduce_ex__, __repr__, __setattr__, __sizeof__, __str__, __subclasshook__, __weakref__, batch_sampler, batch_size, collate_fn, dataset, drop_last, num_workers, pin_memory, sampler, timeout, worker_init_fn'

# %%
def load_checkpoint(device, classes):
    model = load_base_model(device_to, classes)
    model.load_state_dict(torch.load('model_resnet_maxaccu_152_p99.pt', map_location=lambda storage, loc: storage))
    return model

# %%
def model_class_validation(loader, model, device, criterion, classes):
    # initialize lists to monitor test loss and accuracy
    test_loss = 0.0
    class_correct = list(0. for i in range(len(classes)))
    class_total = list(0. for i in range(len(classes)))
    batch_size = 50
    model.eval() # prep model for evaluation
    with torch.no_grad():
        for data, target in loader:
            # forward pass: compute predicted outputs by passing inputs to the model
            data, target = data.to(device), target.to(device)
            print(device, data.size(), target.size())
            output = model.forward(data)
            # calculate the loss
            loss = criterion(output, target)
            # update test loss 
            test_loss += loss.item()*data.size(0)
            # convert output probabilities to predicted class
            _, pred = torch.max(output, 1)
            # compare predictions to true label
            correct = np.squeeze(pred.eq(target.data.view_as(pred)))
            # calculate test accuracy for each object class
            for i in range(target.size(0)):
                label = target.data[i]
                class_correct[label] += correct[i].item()
                class_total[label] += 1

        # calculate and print avg test loss
        test_loss = test_loss/len(loader.dataset)
        print('Test Loss: {:.6f}\n'.format(test_loss))

        for i in range(len(class_total)):
            if class_total[i] > 0:
                 print('Test Accuracy of %5s %5s: %2d%% (%2d/%2d)' % (
                  classes[i],str(i+1) ,100.0 * class_correct[i] / class_total[i],
                  np.sum(class_correct[i]), np.sum(class_total[i])))
            else:
              print('Test Accuracy of %5s: N/A (no training examples)' % (i))

        print('\nTest Accuracy (Overall): %.6f%% (%2d/%2d)' % (
          100. * np.sum(class_correct) / np.sum(class_total),
          np.sum(class_correct), np.sum(class_total)))

# %%
model_class_validation(test_loader, load_checkpoint(device_to, class_names), device_to, nn.NLLLoss(), class_names )
# Out:
# cuda torch.Size([50, 3, 224, 224]) torch.Size([50])
# cuda torch.Size([50, 3, 224, 224]) torch.Size([50])
# cuda torch.Size([16, 3, 224, 224]) torch.Size([16])
# Test Loss: 0.457004
#
# Test Accuracy of autumn     1: 100% (10/10)
# Test Accuracy of beach     2: 87% ( 7/ 8)
# Test Accuracy of christmas     3: 100% (10/10)
# Test Accuracy of easter     4: 88% ( 8/ 9)
# Test Accuracy of fashion     5: 100% (10/10)
# Test Accuracy of friends     6: 100% (10/10)
# Test Accuracy of     6: N/A (no training examples)
# Test Accuracy of landscape     8: 50% ( 4/ 8)
# Test Accuracy of  love     9: 100% ( 8/ 8)
# Test Accuracy of mountains    10: 100% (10/10)
# Test Accuracy of nature    11: 20% ( 2/10)
# Test Accuracy of  snow    12: 80% ( 8/10)
# Test Accuracy of summer    13: 62% ( 5/ 8)
# Test Accuracy of sunset    14: 100% ( 5/ 5)
#
# Test Accuracy (Overall): 83.620690% (97/116)
